# %% [markdown]
# # Dungeon Adventure Game - Instructions
#
# In this exercise, you will build a text-based dungeon adventure game in Python.
#
# You will apply everything you've learned so far, including:
# - Variables
# - Operators
# - Lists
# - Dictionaries
# - Loops
# - Conditionals
# - The `random` module
#
# Follow the prompts in each section to build your game step by step. By the end, you will have a fully functioning game where the player can explore rooms, search for treasure, avoid traps, and see their final score based on the treasures collected.
#
# Complete each section before moving on to the next.

# %%
# Step 1: Player Setup
# Prompt the player for their name.
# Set health to 10.
# Create an empty list to store their inventory.
player_name = input("Enter your adventurer's name: ")
health = 10
inventory = []

# %%
# Step 2: Treasure Dictionary
# Create a dictionary of treasures where the keys are treasure names
# and the values are the gold value of each treasure.
treasures = {
    "Gold Coin": 50,
    "Amulet": 20,
    "Ruby": 100,
    "Staff of the Swamp Goblin": 10,
    "Lockpick Kit": 5,
    "Necronomicon": 200,
    "Ancient Scroll": 30
}

# %%
# Step 3: Game Loop - Moving through 5 rooms
# Use a for loop to represent rooms 1 to 5.
# In each room, display the current room number and the options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# Make sure to handle each option appropriately.


# Step 4: Implement treasure search
# If the player chooses to search, randomly decide if they find treasure or a trap.
# If treasure, randomly pick from the treasure dictionary and add to inventory.
# If trap, deduct 2 health points and print a message.


# Step 5: Check health
# If health drops to 0 or below, print a Game Over message and break the loop.
import random
room = 1
max_rooms = 5

while room <= max_rooms and health > 0:
    print(f"\nRoom {room} - What would you like to do?")
    print("1. Search for treasure")
    print("2. Move to next room")
    print("3. Check health and inventory")
    print("4. Quit the game")
    choice = input("Enter your choice (1-4): ")
    if choice == '1':
        outcome = random.choice(["treasure", "trap", "nothing"])
        if outcome == "treasure":
            treasure = random.choice(list(treasures.keys()))
            inventory.append(treasure)
            print(f"You found a {treasure}! worth {treasures[treasure]} gold.")
        elif outcome == "trap":
            damage = 2
            health -= damage
            print(f"A trap! You lost {damage} health points. Remaining health: {health}")
        else:
            print("You found nothing in this room.")
        if health <=0:
            print("You have succumbed to your injuries. Game Over!")
            break
    elif choice == "2":
        room += 1
    elif choice == "3":
        print(f"Health: {health}")
        print(f"Inventory: {inventory}")
    elif choice == "4":
        print("Thanks for playing! Goodbye!")
        break
    else:
        print("Invalid choice. Your princess is in another castle!")
# Out:
# Room 1 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# You found nothing in this room.
#
# Room 1 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# You found a Gold Coin! worth 50 gold.
#
# Room 1 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Room 2 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Room 3 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# You found nothing in this room.
#
# Room 3 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# You found a Ancient Scroll! worth 30 gold.
#
# Room 3 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# A trap! You lost 2 health points. Remaining health: 8
#
# Room 3 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# Health: 8
# Inventory: ['Gold Coin', 'Ancient Scroll']
#
# Room 3 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Room 4 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# You found nothing in this room.
#
# Room 4 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Room 5 - What would you like to do?
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game

# %%
# Step 6: End of Game Summary
# If the player quits or finishes all rooms, calculate the total value of the collected treasures.
# Loop through the inventory and sum the gold value using the treasure dictionary.
# Print the final health, inventory, and total treasure value.
total_value = sum([treasures[item] for item in inventory])
print("\nGame Over!")
print(f"Player: {player_name}")
print(f"Health: {health}")
print(f"Inventory: {inventory}")
print(f"Total Treasure Value: {total_value} gold")
# Out:
# Game Over!
# Player: Beth
# Health: 8
# Inventory: ['Gold Coin', 'Ancient Scroll']
# Total Treasure Value: 80 gold
